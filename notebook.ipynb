# %%
import sys
import os
print(f"executable is {sys.executable}")
# Out:
# executable is /Users/saviorodrigues/Developer/agents-project/.venv/bin/python

# %%
from dotenv import load_dotenv
load_dotenv()
from crewai import Agent
from crewai import Task

k = os.getenv("OPENAI_API_KEY")
if k:
    print(k[:3])
else: print("not found")
# Out:
# sk-

# %%
from crewai import LLM

# llm = LLM(
#     model="ollama/llama3.2:1b",
#     base_url="http://localhost:11434"
# )

llm = LLM(
    model="gpt-4.1",
    api_key=os.getenv("OPENAI_API_KEY")
)

# # Responses compatable api
# llm = LLM(
#     model="gpt-4.1-mini"
# )

# %% [markdown]
# The verbose parameter is used to enable detailed execution logs for debugging. It is set to False by default.

# %%
senior_technical_writer = Agent(

    role="Senior Technical Writer",
    
    goal="""Craft clear, engaging, and well-structured
            technical content based on research findings""",
    
    backstory="""You are an experienced technical writer
                 with expertise in simplifying complex
                 concepts, structuring content for readability,
                 and ensuring accuracy in documentation.""",
    llm=llm,      
    verbose=True  # Enable logging for debugging
)
print(senior_technical_writer.llm.model)

writing_task = Task(
    description="""Write a well-structured, engaging,
                   and technically accurate article
                   on {topic}.""",
    
    agent=senior_technical_writer, 
    
    
    expected_output="""A polished, detailed, and easy-to-read
                       article on the given topic.""",
)
# Out:
# gpt-4.1

# %%
# Research Analyst Agent: This agent is responsible for conducting in-depth research and summarizing findings concisely.
research_analyst = Agent(
    role="Senior Research Analyst",
    goal="""Find, analyze, and summarize information 
            from various sources to support technical 
            and business-related inquiries.""",
    backstory="""You are a skilled research analyst with expertise 
                 in gathering accurate data, identifying key trends, 
                 and presenting insights in a structured manner.""",
    llm=llm,
    verbose=True
)

# %%
# Code Review Agent: This agent specializes in reviewing code for errors, optimizations, and best practices.
code_reviewer = Agent(
    role="Senior Code Reviewer",
    goal="""Review code for bugs, inefficiencies, and 
            security vulnerabilities while ensuring adherence 
            to best coding practices.""",
    backstory="""You are a seasoned software engineer with years of 
                 experience in writing, reviewing, and optimizing 
                 production-level code in multiple programming languages.""",
    llm=llm,
    verbose=True
)

# %%
from crewai import Crew

crew = Crew(
    agents=[senior_technical_writer],
    tasks=[writing_task],
    verbose=True
)

# Notebooks already run inside an asyncio event loop, so use the async
# entry point and await it instead of the synchronous crew.kickoff().
response = await crew.kickoff_async(inputs={"topic":"AI Agents"})
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 12c813c8-ef5e-4a9e-a01f-7e6bf4d93142                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Write a well-structured, engaging,                                                                       │
# │                     and technically accurate article                                                            │
# │                     on AI Agents.                                                                               │
# │  ID: cf2fa66b-8fc4-4840-9da7-e50f8dc00e81                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Senior Technical Writer                                                                                 │
# │                                                                                                                 │
# │  Task: Write a well-structured, engaging,                                                                       │
# │                     and technically accurate article                                                            │
# │                     on AI Agents.                                                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Senior Technical Writer                                                                                 │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  # Understanding AI Agents: Bridging the Gap Between Intelligence and Action                                    │
# │                                                                                                                 │
# │  Artificial Intelligence (AI) has become an integral part of modern technology, powering everything from        │
# │  virtual assistants and recommendation engines to self-driving cars and robotics. At the core of many           │
# │  cutting-edge AI applications lies the concept of the **AI agent**. But what exactly is an AI agent, how do     │
# │  they work, and why are they so important to the future of technology? In this article, we’ll provide a         │
# │  comprehensive and accessible look into AI agents—their foundations, types, capabilities, and role in shaping   │
# │  intelligent systems.                                                                                           │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## What Is an AI Agent?                                                                                        │
# │                                                                                                                 │
# │  An **AI agent** is an autonomous entity that perceives its environment, processes input data, makes            │
# │  decisions, and executes actions to achieve specific goals. In simple terms, it’s a software or hardware        │
# │  system that “acts” intelligently within its environment.                                                       │
# │                                                                                                                 │
# │  To break it down:                                                                                              │
# │  - **Perception:** The agent collects information from its surroundings using sensors or data feeds.            │
# │  - **Decision-making:** It uses algorithms or learned behaviors to process this information and determine the   │
# │  best action.                                                                                                   │
# │  - **Action:** The agent interacts with the environment via actuators (for physical agents) or application      │
# │  programming interfaces (APIs) for software agents.                                                             │
# │                                                                                                                 │
# │  This “perceive–think–act” cycle defines the foundation of every AI agent.                                      │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## Key Characteristics of AI Agents                                                                            │
# │                                                                                                                 │
# │  AI agents are distinguished by several core features:                                                          │
# │                                                                                                                 │
# │  1. **Autonomy**: They operate without constant human intervention. Agents can make decisions and act           │
# │  independently within defined boundaries.                                                                       │
# │  2. **Adaptivity**: Many AI agents can learn from experience, modifying their behavior to become more           │
# │  effective over time.                                                                                           │
# │  3. **Reactivity**: Agents sense changes in their environment and respond appropriately.                        │
# │  4. **Proactivity**: Beyond merely reacting, intelligent agents can take initiative to achieve their            │
# │  objectives.                                                                                                    │
# │  5. **Goal-Oriented**: They are programmed or trained to prioritize and pursue specific outcomes or             │
# │  objectives.                                                                                                    │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## Types of AI Agents                                                                                          │
# │                                                                                                                 │
# │  AI agents come in many forms, each suited to different challenges. Here are the most common categories:        │
# │                                                                                                                 │
# │  ### 1. Simple Reflex Agents                                                                                    │
# │                                                                                                                 │
# │  These agents act solely based on the current perception, using rule-based decisions (“if–then” logic). For     │
# │  example, a thermostat increases or decreases temperature based on current readings.                            │
# │                                                                                                                 │
# │  **Limitations:** They cannot handle situations requiring memory or learning.                                   │
# │                                                                                                                 │
# │  ### 2. Model-Based Reflex Agents                                                                               │
# │                                                                                                                 │
# │  These improve upon simple agents by maintaining an internal model of the world, allowing them to consider      │
# │  past events when making decisions. For instance, a robot vacuum can remember obstacles previously encountered  │
# │  and avoid them in future runs.                                                                                 │
# │                                                                                                                 │
# │  ### 3. Goal-Based Agents                                                                                       │
# │                                                                                                                 │
# │  Here, the agent weighs different possible actions based on a desired outcome. For example, a chess-playing AI  │
# │  chooses moves that maximize its chances of winning.                                                            │
# │                                                                                                                 │
# │  ### 4. Utility-Based Agents                                                                                    │
# │                                                                                                                 │
# │  These agents not only aim for a goal but also consider multiple factors (or “utilities”) to determine the      │
# │  most desirable outcome. For example, an autonomous vehicle weighs route efficiency, safety, and fuel economy   │
# │  when navigating traffic.                                                                                       │
# │                                                                                                                 │
# │  ### 5. Learning Agents                                                                                         │
# │                                                                                                                 │
# │  These agents improve their performance by learning from past experiences, often using techniques from machine  │
# │  learning. Modern personal assistants (like Siri, Alexa, or Google Assistant) utilize learning to refine        │
# │  responses and anticipate user needs.                                                                           │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## How Do AI Agents Work?                                                                                      │
# │                                                                                                                 │
# │  Let’s break down the operation of a typical AI agent with a simple example: a virtual personal assistant.      │
# │                                                                                                                 │
# │  1. **Perception**: It listens to your voice command through a microphone.                                      │
# │  2. **Processing**: The audio is transformed into text and analyzed using natural language processing (NLP) to  │
# │  understand intent.                                                                                             │
# │  3. **Reasoning & Decision-Making**: Based on the intent, the agent decides what action to take—set a           │
# │  reminder, play music, answer a question.                                                                       │
# │  4. **Action**: It carries out the command (e.g., adds a calendar event).                                       │
# │  5. **Feedback Loop**: It learns from the success or failure of its actions, refining future responses.         │
# │                                                                                                                 │
# │  This process relies on diverse AI fields—machine learning, NLP, knowledge representation, and planning.        │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## Real-World Applications of AI Agents                                                                        │
# │                                                                                                                 │
# │  AI agents are already transforming industries:                                                                 │
# │                                                                                                                 │
# │  - **Finance:** Automated trading agents make decisions in milliseconds based on market conditions.             │
# │  - **Healthcare:** Virtual health assistants triage symptoms, schedule appointments, and provide patient        │
# │  support.                                                                                                       │
# │  - **Manufacturing:** Robotics agents monitor assembly lines, predict maintenance, and optimize workflows.      │
# │  - **Customer Support:** Chatbots handle millions of queries, providing instant help and escalating complex     │
# │  cases to humans.                                                                                               │
# │  - **Smart Homes:** Agents manage energy use, security systems, and entertainment based on user habits.         │
# │  - **Gaming:** Non-player characters (NPCs) and opponents use AI agent logic for challenging, human-like        │
# │  behaviors.                                                                                                     │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## Challenges and Ethical Considerations                                                                       │
# │                                                                                                                 │
# │  Despite their promise, AI agents also pose challenges:                                                         │
# │                                                                                                                 │
# │  - **Data Privacy:** Agents often handle sensitive personal or corporate data, raising security concerns.       │
# │  - **Bias and Fairness:** If trained on biased data, agents can perpetuate unfair outcomes.                     │
# │  - **Transparency & Control:** Users may struggle to understand or manage agents’ autonomous decisions.         │
# │  - **Alignment with Human Values:** Ensuring agents’ goals remain aligned with societal norms and ethics is an  │
# │  ongoing area of research.                                                                                      │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## The Future of AI Agents                                                                                     │
# │                                                                                                                 │
# │  AI agents are evolving rapidly, with advances in deep learning, reinforcement learning, and multi-agent        │
# │  systems. Future agents will:                                                                                   │
# │                                                                                                                 │
# │  - **Collaborate in Teams:** Groups of agents could tackle complex, distributed tasks—like coordinating         │
# │  disaster response or managing smart grids.                                                                     │
# │  - **Learn More Efficiently:** Transfer and meta-learning will allow agents to adapt quicker, using fewer       │
# │  training examples.                                                                                             │
# │  - **Integrate Seamlessly into Daily Life:** From personalized healthcare to adaptive education and autonomous  │
# │  transportation, AI agents will increasingly act as our digital partners.                                       │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## Conclusion                                                                                                  │
# │                                                                                                                 │
# │  AI agents are the engine driving the next generation of intelligent technology. Defined by their autonomy,     │
# │  adaptivity, and goal-driven behavior, they have already demonstrated the capacity to analyze, decide, and      │
# │  act—transforming industries and everyday experiences. As research and development continue, the capabilities   │
# │  and responsibility of AI agents will grow, making it essential to understand not just how they work, but also  │
# │  how they can best serve society safely and ethically.                                                          │
# │                                                                                                                 │
# │  Whether you interact with a chatbot, rely on smart home devices, or benefit from AI-enhanced services, you     │
# │  are already in the ecosystem shaped by AI agents—the invisible workforce of tomorrow’s intelligent world.      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Write a well-structured, engaging,                                                                       │
# │                     and technically accurate article                                                            │
# │                     on AI Agents.                                                                               │
# │  Agent: Senior Technical Writer                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 12c813c8-ef5e-4a9e-a01f-7e6bf4d93142                                                                       │
# │  Final Output: # Understanding AI Agents: Bridging the Gap Between Intelligence and Action                      │
# │                                                                                                                 │
# │  Artificial Intelligence (AI) has become an integral part of modern technology, powering everything from        │
# │  virtual assistants and recommendation engines to self-driving cars and robotics. At the core of many           │
# │  cutting-edge AI applications lies the concept of the **AI agent**. But what exactly is an AI agent, how do     │
# │  they work, and why are they so important to the future of technology? In this article, we’ll provide a         │
# │  comprehensive and accessible look into AI agents—their foundations, types, capabilities, and role in shaping   │
# │  intelligent systems.                                                                                           │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## What Is an AI Agent?                                                                                        │
# │                                                                                                                 │
# │  An **AI agent** is an autonomous entity that perceives its environment, processes input data, makes            │
# │  decisions, and executes actions to achieve specific goals. In simple terms, it’s a software or hardware        │
# │  system that “acts” intelligently within its environment.                                                       │
# │                                                                                                                 │
# │  To break it down:                                                                                              │
# │  - **Perception:** The agent collects information from its surroundings using sensors or data feeds.            │
# │  - **Decision-making:** It uses algorithms or learned behaviors to process this information and determine the   │
# │  best action.                                                                                                   │
# │  - **Action:** The agent interacts with the environment via actuators (for physical agents) or application      │
# │  programming interfaces (APIs) for software agents.                                                             │
# │                                                                                                                 │
# │  This “perceive–think–act” cycle defines the foundation of every AI agent.                                      │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## Key Characteristics of AI Agents                                                                            │
# │                                                                                                                 │
# │  AI agents are distinguished by several core features:                                                          │
# │                                                                                                                 │
# │  1. **Autonomy**: They operate without constant human intervention. Agents can make decisions and act           │
# │  independently within defined boundaries.                                                                       │
# │  2. **Adaptivity**: Many AI agents can learn from experience, modifying their behavior to become more           │
# │  effective over time.                                                                                           │
# │  3. **Reactivity**: Agents sense changes in their environment and respond appropriately.                        │
# │  4. **Proactivity**: Beyond merely reacting, intelligent agents can take initiative to achieve their            │
# │  objectives.                                                                                                    │
# │  5. **Goal-Oriented**: They are programmed or trained to prioritize and pursue specific outcomes or             │
# │  objectives.                                                                                                    │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## Types of AI Agents                                                                                          │
# │                                                                                                                 │
# │  AI agents come in many forms, each suited to different challenges. Here are the most common categories:        │
# │                                                                                                                 │
# │  ### 1. Simple Reflex Agents                                                                                    │
# │                                                                                                                 │
# │  These agents act solely based on the current perception, using rule-based decisions (“if–then” logic). For     │
# │  example, a thermostat increases or decreases temperature based on current readings.                            │
# │                                                                                                                 │
# │  **Limitations:** They cannot handle situations requiring memory or learning.                                   │
# │                                                                                                                 │
# │  ### 2. Model-Based Reflex Agents                                                                               │
# │                                                                                                                 │
# │  These improve upon simple agents by maintaining an internal model of the world, allowing them to consider      │
# │  past events when making decisions. For instance, a robot vacuum can remember obstacles previously encountered  │
# │  and avoid them in future runs.                                                                                 │
# │                                                                                                                 │
# │  ### 3. Goal-Based Agents                                                                                       │
# │                                                                                                                 │
# │  Here, the agent weighs different possible actions based on a desired outcome. For example, a chess-playing AI  │
# │  chooses moves that maximize its chances of winning.                                                            │
# │                                                                                                                 │
# │  ### 4. Utility-Based Agents                                                                                    │
# │                                                                                                                 │
# │  These agents not only aim for a goal but also consider multiple factors (or “utilities”) to determine the      │
# │  most desirable outcome. For example, an autonomous vehicle weighs route efficiency, safety, and fuel economy   │
# │  when navigating traffic.                                                                                       │
# │                                                                                                                 │
# │  ### 5. Learning Agents                                                                                         │
# │                                                                                                                 │
# │  These agents improve their performance by learning from past experiences, often using techniques from machine  │
# │  learning. Modern personal assistants (like Siri, Alexa, or Google Assistant) utilize learning to refine        │
# │  responses and anticipate user needs.                                                                           │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## How Do AI Agents Work?                                                                                      │
# │                                                                                                                 │
# │  Let’s break down the operation of a typical AI agent with a simple example: a virtual personal assistant.      │
# │                                                                                                                 │
# │  1. **Perception**: It listens to your voice command through a microphone.                                      │
# │  2. **Processing**: The audio is transformed into text and analyzed using natural language processing (NLP) to  │
# │  understand intent.                                                                                             │
# │  3. **Reasoning & Decision-Making**: Based on the intent, the agent decides what action to take—set a           │
# │  reminder, play music, answer a question.                                                                       │
# │  4. **Action**: It carries out the command (e.g., adds a calendar event).                                       │
# │  5. **Feedback Loop**: It learns from the success or failure of its actions, refining future responses.         │
# │                                                                                                                 │
# │  This process relies on diverse AI fields—machine learning, NLP, knowledge representation, and planning.        │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## Real-World Applications of AI Agents                                                                        │
# │                                                                                                                 │
# │  AI agents are already transforming industries:                                                                 │
# │                                                                                                                 │
# │  - **Finance:** Automated trading agents make decisions in milliseconds based on market conditions.             │
# │  - **Healthcare:** Virtual health assistants triage symptoms, schedule appointments, and provide patient        │
# │  support.                                                                                                       │
# │  - **Manufacturing:** Robotics agents monitor assembly lines, predict maintenance, and optimize workflows.      │
# │  - **Customer Support:** Chatbots handle millions of queries, providing instant help and escalating complex     │
# │  cases to humans.                                                                                               │
# │  - **Smart Homes:** Agents manage energy use, security systems, and entertainment based on user habits.         │
# │  - **Gaming:** Non-player characters (NPCs) and opponents use AI agent logic for challenging, human-like        │
# │  behaviors.                                                                                                     │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## Challenges and Ethical Considerations                                                                       │
# │                                                                                                                 │
# │  Despite their promise, AI agents also pose challenges:                                                         │
# │                                                                                                                 │
# │  - **Data Privacy:** Agents often handle sensitive personal or corporate data, raising security concerns.       │
# │  - **Bias and Fairness:** If trained on biased data, agents can perpetuate unfair outcomes.                     │
# │  - **Transparency & Control:** Users may struggle to understand or manage agents’ autonomous decisions.         │
# │  - **Alignment with Human Values:** Ensuring agents’ goals remain aligned with societal norms and ethics is an  │
# │  ongoing area of research.                                                                                      │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## The Future of AI Agents                                                                                     │
# │                                                                                                                 │
# │  AI agents are evolving rapidly, with advances in deep learning, reinforcement learning, and multi-agent        │
# │  systems. Future agents will:                                                                                   │
# │                                                                                                                 │
# │  - **Collaborate in Teams:** Groups of agents could tackle complex, distributed tasks—like coordinating         │
# │  disaster response or managing smart grids.                                                                     │
# │  - **Learn More Efficiently:** Transfer and meta-learning will allow agents to adapt quicker, using fewer       │
# │  training examples.                                                                                             │
# │  - **Integrate Seamlessly into Daily Life:** From personalized healthcare to adaptive education and autonomous  │
# │  transportation, AI agents will increasingly act as our digital partners.                                       │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## Conclusion                                                                                                  │
# │                                                                                                                 │
# │  AI agents are the engine driving the next generation of intelligent technology. Defined by their autonomy,     │
# │  adaptivity, and goal-driven behavior, they have already demonstrated the capacity to analyze, decide, and      │
# │  act—transforming industries and everyday experiences. As research and development continue, the capabilities   │
# │  and responsibility of AI agents will grow, making it essential to understand not just how they work, but also  │
# │  how they can best serve society safely and ethically.                                                          │
# │                                                                                                                 │
# │  Whether you interact with a chatbot, rely on smart home devices, or benefit from AI-enhanced services, you     │
# │  are already in the ecosystem shaped by AI agents—the invisible workforce of tomorrow’s intelligent world.      │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
from IPython.display import Markdown

Markdown(response.raw)
# Out:
# # Understanding AI Agents: Bridging the Gap Between Intelligence and Action
#
# Artificial Intelligence (AI) has become an integral part of modern technology, powering everything from virtual assistants and recommendation engines to self-driving cars and robotics. At the core of many cutting-edge AI applications lies the concept of the **AI agent**. But what exactly is an AI agent, how do they work, and why are they so important to the future of technology? In this article, we’ll provide a comprehensive and accessible look into AI agents—their foundations, types, capabilities, and role in shaping intelligent systems.
#
# ---
#
# ## What Is an AI Agent?
#
# An **AI agent** is an autonomous entity that perceives its environment, processes input data, makes decisions, and executes actions to achieve specific goals. In simple terms, it’s a software or hardware system that “acts” intelligently within its environment.
#
# To break it down:
# - **Perception:** The agent collects information from its surroundings using sensors or data feeds.
# - **Decision-making:** It uses algorithms or learned behaviors to process this information and determine the best action.
# - **Action:** The agent interacts with the environment via actuators (for physical agents) or application programming interfaces (APIs) for software agents.
#
# This “perceive–think–act” cycle defines the foundation of every AI agent.
#
# ---
#
# ## Key Characteristics of AI Agents
#
# AI agents are distinguished by several core features:
#
# 1. **Autonomy**: They operate without constant human intervention. Agents can make decisions and act independently within defined boundaries.
# 2. **Adaptivity**: Many AI agents can learn from experience, modifying their behavior to become more effective over time.
# 3. **Reactivity**: Agents sense changes in their environment and respond appropriately.
# 4. **Proactivity**: Beyond merely reacting, intelligent agents can take initiative to achieve their objectives.
# 5. **Goal-Oriented**: They are programmed or trained to prioritize and pursue specific outcomes or objectives.
#
# ---
#
# ## Types of AI Agents
#
# AI agents come in many forms, each suited to different challenges. Here are the most common categories:
#
# ### 1. Simple Reflex Agents
#
# These agents act solely based on the current perception, using rule-based decisions (“if–then” logic). For example, a thermostat increases or decreases temperature based on current readings.
#
# **Limitations:** They cannot handle situations requiring memory or learning.
#
# ### 2. Model-Based Reflex Agents
#
# These improve upon simple agents by maintaining an internal model of the world, allowing them to consider past events when making decisions. For instance, a robot vacuum can remember obstacles previously encountered and avoid them in future runs.
#
# ### 3. Goal-Based Agents
#
# Here, the agent weighs different possible actions based on a desired outcome. For example, a chess-playing AI chooses moves that maximize its chances of winning.
#
# ### 4. Utility-Based Agents
#
# These agents not only aim for a goal but also consider multiple factors (or “utilities”) to determine the most desirable outcome. For example, an autonomous vehicle weighs route efficiency, safety, and fuel economy when navigating traffic.
#
# ### 5. Learning Agents
#
# These agents improve their performance by learning from past experiences, often using techniques from machine learning. Modern personal assistants (like Siri, Alexa, or Google Assistant) utilize learning to refine responses and anticipate user needs.
#
# ---
#
# ## How Do AI Agents Work?
#
# Let’s break down the operation of a typical AI agent with a simple example: a virtual personal assistant.
#
# 1. **Perception**: It listens to your voice command through a microphone.
# 2. **Processing**: The audio is transformed into text and analyzed using natural language processing (NLP) to understand intent.
# 3. **Reasoning & Decision-Making**: Based on the intent, the agent decides what action to take—set a reminder, play music, answer a question.
# 4. **Action**: It carries out the command (e.g., adds a calendar event).
# 5. **Feedback Loop**: It learns from the success or failure of its actions, refining future responses.
#
# This process relies on diverse AI fields—machine learning, NLP, knowledge representation, and planning.
#
# ---
#
# ## Real-World Applications of AI Agents
#
# AI agents are already transforming industries:
#
# - **Finance:** Automated trading agents make decisions in milliseconds based on market conditions.
# - **Healthcare:** Virtual health assistants triage symptoms, schedule appointments, and provide patient support.
# - **Manufacturing:** Robotics agents monitor assembly lines, predict maintenance, and optimize workflows.
# - **Customer Support:** Chatbots handle millions of queries, providing instant help and escalating complex cases to humans.
# - **Smart Homes:** Agents manage energy use, security systems, and entertainment based on user habits.
# - **Gaming:** Non-player characters (NPCs) and opponents use AI agent logic for challenging, human-like behaviors.
#
# ---
#
# ## Challenges and Ethical Considerations
#
# Despite their promise, AI agents also pose challenges:
#
# - **Data Privacy:** Agents often handle sensitive personal or corporate data, raising security concerns.
# - **Bias and Fairness:** If trained on biased data, agents can perpetuate unfair outcomes.
# - **Transparency & Control:** Users may struggle to understand or manage agents’ autonomous decisions.
# - **Alignment with Human Values:** Ensuring agents’ goals remain aligned with societal norms and ethics is an ongoing area of research.
#
# ---
#
# ## The Future of AI Agents
#
# AI agents are evolving rapidly, with advances in deep learning, reinforcement learning, and multi-agent systems. Future agents will:
#
# - **Collaborate in Teams:** Groups of agents could tackle complex, distributed tasks—like coordinating disaster response or managing smart grids.
# - **Learn More Efficiently:** Transfer and meta-learning will allow agents to adapt quicker, using fewer training examples.
# - **Integrate Seamlessly into Daily Life:** From personalized healthcare to adaptive education and autonomous transportation, AI agents will increasingly act as our digital partners.
#
# ---
#
# ## Conclusion
#
# AI agents are the engine driving the next generation of intelligent technology. Defined by their autonomy, adaptivity, and goal-driven behavior, they have already demonstrated the capacity to analyze, decide, and act—transforming industries and everyday experiences. As research and development continue, the capabilities and responsibility of AI agents will grow, making it essential to understand not just how they work, but also how they can best serve society safely and ethically.
#
# Whether you interact with a chatbot, rely on smart home devices, or benefit from AI-enhanced services, you are already in the ecosystem shaped by AI agents—the invisible workforce of tomorrow’s intelligent world.

# %% [markdown]
# # Use tools

# %%
# Write response to output.md file

with open("output.md", "w") as f:
    f.write(response.raw)

# %%
from crewai_tools import FileReadTool

file_read_tool = FileReadTool()

# %%
# Agent that will be responsible for reading and summarizing files
summarizer_agent = Agent(
    role="Senior Document Summarizer",
    goal="Extract and summarize key insights from provided files in 20 words or less.",
    backstory="""You are an expert in document analysis, skilled at extracting 
                 key details, summarizing content, and identifying critical 
                 insights from structured and unstructured text.""",
    tools=[file_read_tool],
    verbose=True
)

# %%
#  Task instructs the agent to read and analyze a file
summarizer_task = Task(
    description=(
        "Use the FileReadTool to read the contents of {file_path}"
        "and provide a summary in 20 words or less. "
        "Ensure the summary captures the key insights "
        "and main points from the document."
    ),
    agent=summarizer_agent,
    tools=[file_read_tool],
    expected_output="A concise 20-word summary of the key points from the file.",
)

# %%
# Crew that executes the file-processing workflow
summarizer_crew = Crew(
    agents=[summarizer_agent],
    tasks=[summarizer_task],
    verbose=True
)

# Run the crew with the file input
# Note: Notebooks already run inside an asyncio event loop, so use the async
# entry point and await it instead of the synchronous kickoff().
result = await summarizer_crew.kickoff_async(inputs={"file_path": "output.md"})
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: b278a511-491d-45d1-8528-47f691167072                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Use the FileReadTool to read the contents of output.mdand provide a summary in 20 words or less. Ensure  │
# │  the summary captures the key insights and main points from the document.                                       │
# │  ID: 4805fb47-c4d5-4770-925e-d70a0727fa6f                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Senior Document Summarizer                                                                              │
# │                                                                                                                 │
# │  Task: Use the FileReadTool to read the contents of output.mdand provide a summary in 20 words or less. Ensure  │
# │  the summary captures the key insights and main points from the document.                                       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────── 🔧 Tool Execution Started (#5) ─────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool: read_a_files_content                                                                                     │
# │  Args: {'file_path': 'output.md', 'start_line': None, 'line_count': None}                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Tool read_a_files_content executed with result: # Understanding AI Agents: Bridging the Gap Between Intelligence and Action
#
# Artificial Intelligence (AI) has become an integral part of modern technology, powering everything from virtual assistants ...
# ╭─────────────────────────────────────── ✅ Tool Execution Completed (#5) ────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool Completed                                                                                                 │
# │  Tool: read_a_files_content                                                                                     │
# │  Output: # Understanding AI Agents: Bridging the Gap Between Intelligence and Action                            │
# │                                                                                                                 │
# │  Artificial Intelligence (AI) has become an integral part of modern technology, powering everything from        │
# │  virtual assistants and recommendation engines to self-driving cars and robotics. At the core of many           │
# │  cutting-edge AI applications lies the concept of the **AI agent**. But what exactly is an AI agent, how do     │
# │  they work, and why are they so important to the future of technology? In this article, we’ll provide a         │
# │  comprehensive and accessible look into AI agents—their foundations, types, capabilities, and role in shaping   │
# │  intelligent systems.                                                                                           │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## What Is an AI Agent?                                                                                        │
# │                                                                                                                 │
# │  An **AI agent** is an autonomous entity that perceives its environment, processes input data, makes            │
# │  decisions, and executes actions to achieve specific goals. In simple terms, it’s a software or hardware        │
# │  system that “acts” intelligently within its environment.                                                       │
# │                                                                                                                 │
# │  To break it down:                                                                                              │
# │  - **Perception:** The agent collects information from its surroundings using sensors or data feeds.            │
# │  - **Decision-making:** It uses algorithms or learned behaviors to process this information and determine the   │
# │  best action.                                                                                                   │
# │  - **Action:** The agent interacts with the environment via actuators (for physical agents) or application      │
# │  programming interfaces (APIs) for software agents.                                                             │
# │                                                                                                                 │
# │  This “perceive–think–act” cycle defines the foundation of every AI agent.                                      │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## Key Characteristics of AI Agents                                                                            │
# │                                                                                                                 │
# │  AI agents are distinguished by several core features:                                                          │
# │                                                                                                                 │
# │  1. **Autonomy**: They operate without constant human intervention. Agents can make decisions and act           │
# │  independently within defined boundaries.                                                                       │
# │  2. **Adaptivity**: Many AI agents can learn from experience, modifying their behavior to become more           │
# │  effective over time.                                                                                           │
# │  3. **Reactivity**: Agents sense changes in their environment and respond appropriately.                        │
# │  4. **Proactivity**: Beyond merely reacting, intelligent agents can take initiative to achieve their            │
# │  objectives.                                                                                                    │
# │  5. **Goal-Oriented**: They are programmed or trained to prioritize and pursue specific outcomes or             │
# │  objectives.                                                                                                    │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## Types of AI Agents                                                                                          │
# │                                                                                                                 │
# │  AI agents come in many forms, each suited to different challenges. Here are the most common categories:        │
# │                                                                                                                 │
# │  ### 1. Simple Reflex Agents                                                                                    │
# │                                                                                                                 │
# │  These agents act solely based on the current perception, using rule-based decisions (“if–then” logic). For     │
# │  example, a thermostat increases or decreases temperature based on current readings.                            │
# │                                                                                                                 │
# │  **Limitations:** They cannot handle situations requiring memory or learning.                                   │
# │                                                                                                                 │
# │  ### 2. Model-Based Reflex Agents                                                                               │
# │                                                                                                                 │
# │  These improve upon simple agents by maintaining an internal model of the world, allowing them to consider      │
# │  past events when making decisions. For instance, a robot vacuum can remember obstacles previously encountered  │
# │  and avoid them in future runs.                                                                                 │
# │                                                                                                                 │
# │  ### 3. Goal-Based Agents                                                                                       │
# │                                                                                                                 │
# │  Here, the agent weighs different possible actions based on a desired outcome. For example, a chess-playing AI  │
# │  chooses moves that maximize its chances of winning.                                                            │
# │                                                                                                                 │
# │  ### 4. Utility-Based Agents                                                                                    │
# │                                                                                                                 │
# │  These agents not only aim for a goal but also consider multiple factors (or “utilities”) to determine the      │
# │  most desirable outcome. For example, an autonomous vehicle weighs route efficiency, safety, and fuel economy   │
# │  when navigating traffic.                                                                                       │
# │                                                                                                                 │
# │  ### 5. Learning Agents                                                                                         │
# │                                                                                                                 │
# │  These agents improve their performance by learning from past experiences, often using techniques from machine  │
# │  learning. Modern personal assistants (like Siri, Alexa, or Google Assistant) utilize learning to refine        │
# │  responses and anticipate user needs.                                                                           │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## How Do AI Agents Work?                                                                                      │
# │                                                                                                                 │
# │  Let’s break down the operation of a typical AI agent with a simple example: a virtual personal assistant.      │
# │                                                                                                                 │
# │  1. **Perception**: It listens to your voice command through a microphone.                                      │
# │  2. **Processing**: The audio is transformed into text and analyzed using natural language processing (NLP) to  │
# │  understand intent.                                                                                             │
# │  3. **Reasoning & Decision-Making**: Based on the intent, the agent decides what action to take—set a           │
# │  reminder, play music, answer a question.                                                                       │
# │  4. **Action**: It carries out the command (e.g., adds a calendar event).                                       │
# │  5. **Feedback Loop**: It learns from the success or failure of its actions, refining future responses.         │
# │                                                                                                                 │
# │  This process relies on diverse AI fields—machine learning, NLP, knowledge representation, and planning.        │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## Real-World Applications of AI Agents                                                                        │
# │                                                                                                                 │
# │  AI agents are already transforming industries:                                                                 │
# │                                                                                                                 │
# │  - **Finance:** Automated trading agents make decisions in milliseconds based on market conditions.             │
# │  - **Healthcare:** Virtual health assistants triage symptoms, schedule appointments, and provide patient        │
# │  support.                                                                                                       │
# │  - **Manufacturing:** Robotics agents monitor assembly lines, predict maintenance, and optimize workflows.      │
# │  - **Customer Support:** Chatbots handle millions of queries, providing instant help and escalating complex     │
# │  cases to humans.                                                                                               │
# │  - **Smart Homes:** Agents manage energy use, security systems, and entertainment based on user habits.         │
# │  - **Gaming:** Non-player characters (NPCs) and opponents use AI agent logic for challenging, human-like        │
# │  behaviors.                                                                                                     │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## Challenges and Ethical Considerations                                                                       │
# │                                                                                                                 │
# │  Despite their promise, AI agents also pose challenges:                                                         │
# │                                                                                                                 │
# │  - **Data Privacy:** Agents often handle sensitive personal or corporate data, raising security concerns.       │
# │  - **Bias and Fairness:** If trained on biased data, agents can perpetuate unfair outcomes.                     │
# │  - **Transparency & Control:** Users may struggle to understand or manage agents’ autonomous decisions.         │
# │  - **Alignment with Human Values:** Ensuring agents’ goals remain aligned with societal norms and ethics is an  │
# │  ongoing area of research.                                                                                      │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## The Future of AI Agents                                                                                     │
# │                                                                                                                 │
# │  AI agents are evolving rapidly, with advances in deep learning, reinforcement learning, and multi-agent        │
# │  systems. Future agents will:                                                                                   │
# │                                                                                                                 │
# │  - **Collaborate in Teams:** Groups of agents could tackle complex, distributed tasks—like coordinating         │
# │  disaster response or managing smart grids.                                                                     │
# │  - **Learn More Efficiently:** Transfer and meta-learning will allow agents to adapt quicker, using fewer       │
# │  training examples.                                                                                             │
# │  - **Integrate Seamlessly into Daily Life:** From personalized healthcare to adaptive education and autonomous  │
# │  transportation, AI agents will increasingly act as our digital partners.                                       │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## Conclusion                                                                                                  │
# │                                                                                                                 │
# │  AI agents are the engine driving the next generation of intelligent technology. Defined by their autonomy,     │
# │  adaptivity, and goal-driven behavior, they have already demonstrated the capacity to analyze, decide, and      │
# │  act—transforming industries and everyday experiences. As research and development continue, the capabilities   │
# │  and responsibility of AI agents will grow, making it essential to understand not just how they work, but also  │
# │  how they can best serve society safely and ethically.                                                          │
# │                                                                                                                 │
# │  Whether you interact with a chatbot, rely on smart home devices, or benefit from AI-enhanced services, you     │
# │  are already in the ecosystem shaped by AI agents—the invisible workforce of tomorrow’s intelligent world.      │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Senior Document Summarizer                                                                              │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  AI agents perceive, decide, and act autonomously with adaptivity and goal-orientation, transforming            │
# │  industries and raising ethical challenges in intelligent systems.                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Use the FileReadTool to read the contents of output.mdand provide a summary in 20 words or less. Ensure  │
# │  the summary captures the key insights and main points from the document.                                       │
# │  Agent: Senior Document Summarizer                                                                              │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: b278a511-491d-45d1-8528-47f691167072                                                                       │
# │  Final Output: AI agents perceive, decide, and act autonomously with adaptivity and goal-orientation,           │
# │  transforming industries and raising ethical challenges in intelligent systems.                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
# Print Output
Markdown(result.raw)
# Out:
# AI agents perceive, decide, and act autonomously with adaptivity and goal-orientation, transforming industries and raising ethical challenges in intelligent systems.
